# %% [markdown]
# ## <span style="color:#ff5f27;"> 📡 Connecting to Hopsworks Feature Store </span>

# %%
import hopsworks

project = hopsworks.login()

fs = project.get_feature_store()
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
#
# Multiple projects found.
#
# 	 (1) ID2223_Anton
# 	 (2) ID2223_Ernest
#
# Enter project to access: 2
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/5476
# Connected. Call `.close()` to terminate connection gracefully.

# %%
air_quality_fg = fs.get_or_create_feature_group(
    name = 'poland_air_quality_fg',
    version = 1
)
weather_fg = fs.get_or_create_feature_group(
    name = 'poland_weather_fg',
    version = 1
)
meta_fg = fs.get_or_create_feature_group(
    name = 'poland_meta_fg',
    version = 1
)

# %%
query = air_quality_fg.select(['date', 'pm10', 'city'])\
                              .join(weather_fg.select_all())\
                              .join(meta_fg.select(['area', 'density', 'no_people']))
# Out:
#   File "/var/folders/8x/sm4wjnfx3q36gjxsbvws03_h0000gn/T/ipykernel_9916/2759431442.py", line 3
#     .join(meta_fg.select(['area', 'density', 'no_people']))
#
# ^
# SyntaxError: unexpected EOF while parsing

# %%
query.read()
# Out:
# 2023-01-12 20:57:27,967 INFO: USE `id2223_ernest_featurestore`
# 2023-01-12 20:57:28,440 INFO: SELECT `fg2`.`date` `date`, `fg2`.`pm10` `pm10`, `fg2`.`city` `city`, `fg0`.`tempmax` `tempmax`, `fg0`.`tempmin` `tempmin`, `fg0`.`temp` `temp`, `fg0`.`feelslikemax` `feelslikemax`, `fg0`.`feelslikemin` `feelslikemin`, `fg0`.`feelslike` `feelslike`, `fg0`.`dew` `dew`, `fg0`.`humidity` `humidity`, `fg0`.`precip` `precip`, `fg0`.`precipprob` `precipprob`, `fg0`.`precipcover` `precipcover`, `fg0`.`snow` `snow`, `fg0`.`snowdepth` `snowdepth`, `fg0`.`windgust` `windgust`, `fg0`.`windspeed` `windspeed`, `fg0`.`winddir` `winddir`, `fg0`.`cloudcover` `cloudcover`, `fg0`.`visibility` `visibility`, `fg0`.`solarradiation` `solarradiation`, `fg0`.`solarenergy` `solarenergy`, `fg0`.`uvindex` `uvindex`, `fg0`.`conditions` `conditions`, `fg1`.`lon` `lon`, `fg1`.`lat` `lat`, `fg1`.`area` `area`, `fg1`.`density` `density`, `fg1`.`no_people` `no_people`
# FROM `id2223_ernest_featurestore`.`poland_air_quality_fg_1` `fg2`
# INNER JOIN `id2223_ernest_featurestore`.`poland_weather_fg_1` `fg0` ON `fg2`.`date` = `fg0`.`date` AND `fg2`.`city` = `fg0`.`city`
# INNER JOIN `id2223_ernest_featurestore`.`poland_meta_fg_1` `fg1` ON `fg2`.`city` = `fg1`.`city`
#                date  pm10            city  tempmax  tempmin  temp  \
# 0     1652392800000  19.0  biała podlaska     20.6      7.3  14.9
# 1     1664488800000  35.0  biała podlaska     12.9      2.6   8.3
# 2     1664920800000  18.0  biała podlaska     16.4      7.1  11.2
# 3     1665525600000  42.0  biała podlaska     13.5      1.1   7.7
# 4     1661032800000  10.0  biała podlaska     23.7     16.9  19.9
# ...             ...   ...             ...      ...      ...   ...
# 1031  1665871200000  26.0        katowice     19.3     10.2  14.3
# 1032  1668553200000   9.0        katowice      7.8      2.2   6.4
# 1033  1667170800000  25.0        katowice     20.8      5.8  11.9
# 1034  1670799600000  22.0        katowice     -1.2     -3.9  -2.8
# 1035  1667862000000  23.0        katowice     15.1      1.6   7.9
#
#       feelslikemax  feelslikemin  feelslike   dew  ...  visibility  \
# 0             20.6           7.3       14.9   6.2  ...        27.0
# 1             12.9           2.6        8.3   6.5  ...         7.6
# 2             16.4           5.9       10.9   8.1  ...        18.1
# 3             13.5          -0.5        7.3   4.5  ...        11.3
# 4             23.7          16.9       19.9  16.7  ...        23.7
# ...            ...           ...        ...   ...  ...         ...
# 1031          19.3          10.2       14.3  10.7  ...        19.1
# 1032           7.8          -1.6        5.3   5.8  ...         5.0
# 1033          20.8           5.8       11.9   9.0  ...        11.3
# 1034          -3.9          -9.7       -7.2  -3.9  ...         4.4
# 1035          15.1          -0.2        7.3   5.1  ...        17.5
#
#       solarradiation  solarenergy  uvindex              conditions        lon  \
# 0              293.1         25.4        8        Partially cloudy  52.033333
# 1              100.4          8.6        5  Rain, Partially cloudy  52.033333
# 2               81.9          7.0        4  Rain, Partially cloudy  52.033333
# 3              129.3         11.1        5        Partially cloudy  52.033333
# 4              175.1         15.1        7        Partially cloudy  52.033333
# ...              ...          ...      ...                     ...        ...
# 1031            67.1          5.9        3  Rain, Partially cloudy  50.264167
# 1032             3.1          0.1        0          Rain, Overcast  50.264167
# 1033            67.2          5.9        3        Partially cloudy  50.264167
# 1034            10.7          1.0        1          Snow, Overcast  50.264167
# 1035            60.0          5.2        3        Partially cloudy  50.264167
#
#              lat    area  density  no_people
# 0      23.116667   49.40  1152.06      56942
# 1      23.116667   49.40  1152.06      56942
# 2      23.116667   49.40  1152.06      56942
# 3      23.116667   49.40  1152.06      56942
# 4      23.116667   49.40  1152.06      56942
# ...          ...     ...      ...        ...
# 1031   19.023611  164.64  1742.90     286960
# 1032   19.023611  164.64  1742.90     286960
# 1033   19.023611  164.64  1742.90     286960
# 1034   19.023611  164.64  1742.90     286960
# 1035   19.023611  164.64  1742.90     286960
#
# [1036 rows x 30 columns]

# %% [markdown]
# ---
#
# ## <span style="color:#ff5f27;"> 🖍 Feature View Creation and Retrieving </span>

# %%
query_show = query.show(5)
col_names = query_show.columns

                                         
query_show
# Out:
# 2023-01-12 20:58:08,634 INFO: USE `id2223_ernest_featurestore`
# 2023-01-12 20:58:09,761 INFO: SELECT `fg2`.`date` `date`, `fg2`.`pm10` `pm10`, `fg2`.`city` `city`, `fg0`.`tempmax` `tempmax`, `fg0`.`tempmin` `tempmin`, `fg0`.`temp` `temp`, `fg0`.`feelslikemax` `feelslikemax`, `fg0`.`feelslikemin` `feelslikemin`, `fg0`.`feelslike` `feelslike`, `fg0`.`dew` `dew`, `fg0`.`humidity` `humidity`, `fg0`.`precip` `precip`, `fg0`.`precipprob` `precipprob`, `fg0`.`precipcover` `precipcover`, `fg0`.`snow` `snow`, `fg0`.`snowdepth` `snowdepth`, `fg0`.`windgust` `windgust`, `fg0`.`windspeed` `windspeed`, `fg0`.`winddir` `winddir`, `fg0`.`cloudcover` `cloudcover`, `fg0`.`visibility` `visibility`, `fg0`.`solarradiation` `solarradiation`, `fg0`.`solarenergy` `solarenergy`, `fg0`.`uvindex` `uvindex`, `fg0`.`conditions` `conditions`, `fg1`.`lon` `lon`, `fg1`.`lat` `lat`, `fg1`.`area` `area`, `fg1`.`density` `density`, `fg1`.`no_people` `no_people`
# FROM `id2223_ernest_featurestore`.`poland_air_quality_fg_1` `fg2`
# INNER JOIN `id2223_ernest_featurestore`.`poland_weather_fg_1` `fg0` ON `fg2`.`date` = `fg0`.`date` AND `fg2`.`city` = `fg0`.`city`
# INNER JOIN `id2223_ernest_featurestore`.`poland_meta_fg_1` `fg1` ON `fg2`.`city` = `fg1`.`city`
#             date  pm10            city  tempmax  tempmin  temp  feelslikemax  \
# 0  1652392800000  19.0  biała podlaska     20.6      7.3  14.9          20.6
# 1  1664488800000  35.0  biała podlaska     12.9      2.6   8.3          12.9
# 2  1664920800000  18.0  biała podlaska     16.4      7.1  11.2          16.4
# 3  1665525600000  42.0  biała podlaska     13.5      1.1   7.7          13.5
# 4  1661032800000  10.0  biała podlaska     23.7     16.9  19.9          23.7
#
#    feelslikemin  feelslike   dew  ...  visibility  solarradiation  \
# 0           7.3       14.9   6.2  ...        27.0           293.1
# 1           2.6        8.3   6.5  ...         7.6           100.4
# 2           5.9       10.9   8.1  ...        18.1            81.9
# 3          -0.5        7.3   4.5  ...        11.3           129.3
# 4          16.9       19.9  16.7  ...        23.7           175.1
#
#    solarenergy  uvindex              conditions        lon         lat  area  \
# 0         25.4        8        Partially cloudy  52.033333   23.116667  49.4
# 1          8.6        5  Rain, Partially cloudy  52.033333   23.116667  49.4
# 2          7.0        4  Rain, Partially cloudy  52.033333   23.116667  49.4
# 3         11.1        5        Partially cloudy  52.033333   23.116667  49.4
# 4         15.1        7        Partially cloudy  52.033333   23.116667  49.4
#
#    density  no_people
# 0  1152.06      56942
# 1  1152.06      56942
# 2  1152.06      56942
# 3  1152.06      56942
# 4  1152.06      56942
#
# [5 rows x 30 columns]

# %%
category_cols = ['city','date','conditions']

pred_col = "pm10"
mapping_transformers = {col_name:fs.get_transformation_function(name='standard_scaler') for col_name in col_names if col_name not in category_cols and col_name != pred_col}
category_cols = {col_name:fs.get_transformation_function(name='label_encoder') for col_name in category_cols if col_name not in ['date','aqi']}

mapping_transformers.update(category_cols)

# %%
feature_view = fs.create_feature_view(
    name = 'poland_air_quality_fv',
    version = 1,
    transformation_functions = mapping_transformers,
    query = query
)
# Out:
# Feature view created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/5476/fs/5383/fv/poland_air_quality_fv/version/1

# %% [markdown]
# For now `Feature View` is saved in Hopsworks and you can retrieve it using `FeatureStore.get_feature_view()`.

# %%
feature_view = fs.get_feature_view(
    name = 'poland_air_quality_fv',
    version = 1
)

# %%
query.read()
# Out:
# 2023-01-12 21:11:18,993 INFO: USE `id2223_ernest_featurestore`
# 2023-01-12 21:11:19,592 INFO: SELECT `fg2`.`date` `date`, `fg2`.`pm10` `pm10`, `fg2`.`city` `city`, `fg0`.`tempmax` `tempmax`, `fg0`.`tempmin` `tempmin`, `fg0`.`temp` `temp`, `fg0`.`feelslikemax` `feelslikemax`, `fg0`.`feelslikemin` `feelslikemin`, `fg0`.`feelslike` `feelslike`, `fg0`.`dew` `dew`, `fg0`.`humidity` `humidity`, `fg0`.`precip` `precip`, `fg0`.`precipprob` `precipprob`, `fg0`.`precipcover` `precipcover`, `fg0`.`snow` `snow`, `fg0`.`snowdepth` `snowdepth`, `fg0`.`windgust` `windgust`, `fg0`.`windspeed` `windspeed`, `fg0`.`winddir` `winddir`, `fg0`.`cloudcover` `cloudcover`, `fg0`.`visibility` `visibility`, `fg0`.`solarradiation` `solarradiation`, `fg0`.`solarenergy` `solarenergy`, `fg0`.`uvindex` `uvindex`, `fg0`.`conditions` `conditions`, `fg1`.`lon` `lon`, `fg1`.`lat` `lat`, `fg1`.`area` `area`, `fg1`.`density` `density`, `fg1`.`no_people` `no_people`
# FROM `id2223_ernest_featurestore`.`poland_air_quality_fg_1` `fg2`
# INNER JOIN `id2223_ernest_featurestore`.`poland_weather_fg_1` `fg0` ON `fg2`.`date` = `fg0`.`date` AND `fg2`.`city` = `fg0`.`city`
# INNER JOIN `id2223_ernest_featurestore`.`poland_meta_fg_1` `fg1` ON `fg2`.`city` = `fg1`.`city`
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hsfs/engine/python.py in _sql_offline(self, sql_query, feature_store, dataframe_type)
#      89         with self._create_hive_connection(feature_store) as hive_conn:
# ---> 90             result_df = pd.read_sql(sql_query, hive_conn)
#      91         return self._return_dataframe_type(result_df, dataframe_type)
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     601     if isinstance(pandas_sql, SQLiteDatabase):
# --> 602         return pandas_sql.read_query(
#     603             sql,
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2115         args = _convert_params(sql, params)
# -> 2116         cursor = self.execute(*args)
#    2117         columns = [col_desc[0] for col_desc in cursor.description]
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pyhive/hive.py in execute(self, operation, parameters, **kwargs)
#     406         _logger.debug(req)
# --> 407         response = self._connection.client.ExecuteStatement(req)
#     408         _check_status(response)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/TCLIService/TCLIService.py in ExecuteStatement(self, req)
#     282         self.send_ExecuteStatement(req)
# --> 283         return self.recv_ExecuteStatement()
#     284
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/TCLIService/TCLIService.py in recv_ExecuteStatement(self)
#     294         iprot = self._iprot
# --> 295         (fname, mtype, rseqid) = iprot.readMessageBegin()
#     296         if mtype == TMessageType.EXCEPTION:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/thrift/protocol/TBinaryProtocol.py in readMessageBegin(self)
#     133     def readMessageBegin(self):
# --> 134         sz = self.readI32()
#     135         if sz < 0:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/thrift/protocol/TBinaryProtocol.py in readI32(self)
#     216     def readI32(self):
# --> 217         buff = self.trans.readAll(4)
#     218         val, = unpack('!i', buff)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/thrift/transport/TTransport.py in readAll(self, sz)
#      61         while (have < sz):
# ---> 62             chunk = self.read(sz - have)
#      63             chunkLen = len(chunk)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/thrift/transport/TTransport.py in read(self, sz)
#     163             return ret
# --> 164         self.__rbuf = BufferIO(self.__trans.read(max(sz, self.__rbuf_size)))
#     165         return self.__rbuf.read(sz)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/thrift/transport/TSocket.py in read(self, sz)
#     149         try:
# --> 150             buff = self.handle.recv(sz)
#     151         except socket.error as e:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in recv(self, buflen, flags)
#    1225                     self.__class__)
# -> 1226             return self.read(buflen)
#    1227         else:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in read(self, len, buffer)
#    1100             else:
# -> 1101                 return self._sslobj.read(len)
#    1102         except SSLError as x:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# /var/folders/8x/sm4wjnfx3q36gjxsbvws03_h0000gn/T/ipykernel_9916/620379797.py in <module>
# ----> 1 query.read()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hsfs/constructor/query.py in read(self, online, dataframe_type, read_options)
#     106         sql_query, online_conn = self._prep_read(online, read_options)
#     107
# --> 108         return engine.get_instance().sql(
#     109             sql_query,
#     110             self._feature_store_name,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hsfs/engine/python.py in sql(self, sql_query, feature_store, online_conn, dataframe_type, read_options)
#      82     def sql(self, sql_query, feature_store, online_conn, dataframe_type, read_options):
#      83         if not online_conn:
# ---> 84             return self._sql_offline(sql_query, feature_store, dataframe_type)
#      85         else:
#      86             return self._jdbc(sql_query, online_conn, dataframe_type, read_options)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hsfs/engine/python.py in _sql_offline(self, sql_query, feature_store, dataframe_type)
#      88     def _sql_offline(self, sql_query, feature_store, dataframe_type):
#      89         with self._create_hive_connection(feature_store) as hive_conn:
# ---> 90             result_df = pd.read_sql(sql_query, hive_conn)
#      91         return self._return_dataframe_type(result_df, dataframe_type)
#      92
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pyhive/hive.py in __exit__(self, exc_type, exc_val, exc_tb)
#     256     def __exit__(self, exc_type, exc_val, exc_tb):
#     257         """Call close"""
# --> 258         self.close()
#     259
#     260     def close(self):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pyhive/hive.py in close(self)
#     261         """Close the underlying session and Thrift transport"""
#     262         req = ttypes.TCloseSessionReq(sessionHandle=self._sessionHandle)
# --> 263         response = self._client.CloseSession(req)
#     264         self._transport.close()
#     265         _check_status(response)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/TCLIService/TCLIService.py in CloseSession(self, req)
#     219         """
#     220         self.send_CloseSession(req)
# --> 221         return self.recv_CloseSession()
#     222
#     223     def send_CloseSession(self, req):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/TCLIService/TCLIService.py in recv_CloseSession(self)
#     238             raise x
#     239         result = CloseSession_result()
# --> 240         result.read(iprot)
#     241         iprot.readMessageEnd()
#     242         if result.success is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/TCLIService/TCLIService.py in read(self, iprot)
#    1623                 if ftype == TType.STRUCT:
#    1624                     self.success = TCloseSessionResp()
# -> 1625                     self.success.read(iprot)
#    1626                 else:
#    1627                     iprot.skip(ftype)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/TCLIService/ttypes.py in read(self, iprot)
#    3452                     iprot.skip(ftype)
#    3453             else:
# -> 3454                 iprot.skip(ftype)
#    3455             iprot.readFieldEnd()
#    3456         iprot.readStructEnd()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/thrift/protocol/TProtocol.py in skip(self, ttype)
#     212                 if ttype == TType.STOP:
#     213                     break
# --> 214                 self.skip(ttype)
#     215                 self.readFieldEnd()
#     216             self.readStructEnd()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/thrift/protocol/TProtocol.py in skip(self, ttype)
#     212                 if ttype == TType.STOP:
#     213                     break
# --> 214                 self.skip(ttype)
#     215                 self.readFieldEnd()
#     216             self.readStructEnd()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/thrift/protocol/TProtocol.py in skip(self, ttype)
#     205             self.readDouble()
#     206         elif ttype == TType.STRING:
# --> 207             self.readString()
#     208         elif ttype == TType.STRUCT:
#     209             name = self.readStructBegin()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/thrift/protocol/TProtocol.py in readString(self)
#     183
#     184     def readString(self):
# --> 185         return binary_to_str(self.readBinary())
#     186
#     187     def readBinary(self):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/thrift/compat.py in binary_to_str(bin_val)
#      38
#      39     def binary_to_str(bin_val):
# ---> 40         return bin_val.decode('utf8')
#      41
#      42     def str_to_binary(str_val):
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 0-1: invalid continuation byte

# %%
feature_view.create_training_data()
# Out:
# Training dataset job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai/p/5476/jobs/named/poland_air_quality_fv_1_1_create_fv_td_12012023195933/executions
# ---------------------------------------------------------------------------
# FeatureStoreException                     Traceback (most recent call last)
# /var/folders/8x/sm4wjnfx3q36gjxsbvws03_h0000gn/T/ipykernel_9916/862072044.py in <module>
# ----> 1 feature_view.create_training_data()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hsfs/feature_view.py in create_training_data(self, start_time, end_time, storage_connector, location, description, data_format, coalesce, seed, statistics_config, write_options)
#     412         )
#     413         # td_job is used only if the python engine is used
# --> 414         td, td_job = self._feature_view_engine.create_training_dataset(
#     415             self, td, write_options
#     416         )
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hsfs/core/feature_view_engine.py in create_training_dataset(self, feature_view_obj, training_dataset_obj, user_write_options)
#     140             feature_view_obj, training_dataset_obj
#     141         )
# --> 142         td_job = self.compute_training_dataset(
#     143             feature_view_obj,
#     144             user_write_options,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hsfs/core/feature_view_engine.py in compute_training_dataset(self, feature_view_obj, user_write_options, training_dataset_obj, training_dataset_version)
#     287             with_label=True,
#     288         )
# --> 289         td_job = engine.get_instance().write_training_dataset(
#     290             training_dataset_obj,
#     291             batch_query,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hsfs/engine/python.py in write_training_dataset(self, training_dataset, dataset, user_write_options, save_mode, feature_view_obj, to_df)
#     619         # If the user passed the wait_for_job option consider it,
#     620         # otherwise use the default True
# --> 621         self._wait_for_job(td_job, user_write_options)
#     622
#     623         return td_job
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hsfs/engine/python.py in _wait_for_job(self, job, user_write_options)
#     734                 return
#     735             elif execution.final_status.lower() == "failed":
# --> 736                 raise exceptions.FeatureStoreException(
#     737                     "The Hopsworks Job failed, use the Hopsworks UI to access the job logs"
#     738                 )
#
# FeatureStoreException: The Hopsworks Job failed, use the Hopsworks UI to access the job logs
