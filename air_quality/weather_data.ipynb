# %%
# %%capture
# !pip3 install requests

# %%
# !pip3 freeze | grep requests
# Out:
# requests==2.28.2

# %%
# %%capture
# !pip3 install openpyxl

# %%
import requests
import pandas as pd
from pandas import json_normalize


df_meta = pd.read_excel('data_poland/meta.xlsx')
#print(df_meta)

cities = df_meta['city']
print(cities[0])

api = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/" + str(cities[0]) + "?unitGroup=metric&key=Y9WAHX926KF5CMMMJANUVJCJF&contentType=json"
print(api)
response = requests.get(f"{api}")

    #print(f"Response: {response.json()}")

if response.status_code == 200:
    print("successful fetch")
    r = response.json()
    df = json_normalize(r)

    for i in range(1, len(cities)):
        api = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/" + str(cities[i]) + "?unitGroup=metric&key=Y9WAHX926KF5CMMMJANUVJCJF&contentType=json"
        response = requests.get(f"{api}")

        #print(f"Response: {response.json()}")

        if response.status_code == 200:
            print("successful fetch")
            r = response.json()
            #df.append(json_normalize(r))
            df = pd.concat([df, json_normalize(r)], ignore_index = True)
# Out:
# Biała Podlaska
# https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Biała Podlaska?unitGroup=metric&key=Y9WAHX926KF5CMMMJANUVJCJF&contentType=json
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch

# %%
df
# Out:
#     queryCost  latitude  longitude  \
# 0           1   52.0327    23.1163
# 1           1   53.1401    23.1826
# 2           1   49.8255    19.0507
# 3           1   53.1193    18.0081
# 4           1   54.3531    18.6511
# 5           1   52.7303    15.2356
# 6           1   51.7721    18.1009
# 7           1   50.2564    19.0310
# 8           1   54.1905    16.1824
# 9           1   50.0605    19.9324
# 10          1   51.2479    22.5660
# 11          1   52.4095    16.9383
# 12          1   51.4022    21.1466
# 13          1   50.0397    22.0091
# 14          1   54.1016    22.9394
# 15          1   53.4252    14.5555
# 16          1   53.7125    16.7034
# 17          1   52.2356    21.0104
# 18          1   51.1082    17.0269
# 19          1   53.1785    22.0611
#
#                                 resolvedAddress              address  \
# 0        Biała Podlaska, Woj. Lubelskie, Polska       Biała Podlaska
# 1             Białystok, Woj. Podlaskie, Polska            Białystok
# 2           Bielsko-Biała, Woj. Śląskie, Polska        Bielsko-Biała
# 3    Bydgoszcz, Woj. Kujawsko-Pomorskie, Polska            Bydgoszcz
# 4                Gdańsk, Woj. Pomorskie, Polska               Gdańsk
# 5    Gorzów Wielkopolski, Woj. Lubuskie, Polska  Gorzów Wielkopolski
# 6            Kalisz, Woj. Wielkopolskie, Polska               Kalisz
# 7                Katowice, Woj. Śląskie, Polska             Katowice
# 8     Koszalin, Woj. Zachodniopomorskie, Polska             Koszalin
# 9              Kraków, Woj. Małopolskie, Polska               Kraków
# 10               Lublin, Woj. Lubelskie, Polska               Lublin
# 11           Poznań, Woj. Wielkopolskie, Polska               Poznań
# 12              Radom, Woj. Mazowieckie, Polska                Radom
# 13           Rzeszów, Woj. Podkarpackie, Polska              Rzeszów
# 14              Suwałki, Woj. Podlaskie, Polska              Suwałki
# 15    Szczecin, Woj. Zachodniopomorskie, Polska             Szczecin
# 16  Szczecinek, Woj. Zachodniopomorskie, Polska           Szczecinek
# 17           Warszawa, Woj. Mazowieckie, Polska             Warszawa
# 18           Wrocław, Woj. Dolnośląskie, Polska              Wrocław
# 19                Łomża, Woj. Podlaskie, Polska                Łomża
#
#          timezone  tzoffset  \
# 0   Europe/Warsaw       1.0
# 1   Europe/Warsaw       1.0
# 2   Europe/Warsaw       1.0
# 3   Europe/Warsaw       1.0
# 4   Europe/Warsaw       1.0
# 5   Europe/Warsaw       1.0
# 6   Europe/Warsaw       1.0
# 7   Europe/Warsaw       1.0
# 8   Europe/Warsaw       1.0
# 9   Europe/Warsaw       1.0
# 10  Europe/Warsaw       1.0
# 11  Europe/Warsaw       1.0
# 12  Europe/Warsaw       1.0
# 13  Europe/Warsaw       1.0
# 14  Europe/Warsaw       1.0
# 15  Europe/Warsaw       1.0
# 16  Europe/Warsaw       1.0
# 17  Europe/Warsaw       1.0
# 18  Europe/Warsaw       1.0
# 19  Europe/Warsaw       1.0
#
#                                           description  \
# 0   Similar temperatures continuing with a chance ...
# 1   Similar temperatures continuing with a chance ...
# 2   Similar temperatures continuing with a chance ...
# 3   Similar temperatures continuing with a chance ...
# 4   Similar temperatures continuing with a chance ...
# 5   Similar temperatures continuing with a chance ...
# 6   Similar temperatures continuing with a chance ...
# 7   Similar temperatures continuing with a chance ...
# 8   Similar temperatures continuing with a chance ...
# 9   Similar temperatures continuing with a chance ...
# 10  Similar temperatures continuing with a chance ...
# 11  Similar temperatures continuing with a chance ...
# 12  Similar temperatures continuing with a chance ...
# 13  Similar temperatures continuing with a chance ...
# 14  Similar temperatures continuing with a chance ...
# 15  Similar temperatures continuing with a chance ...
# 16  Similar temperatures continuing with a chance ...
# 17  Similar temperatures continuing with a chance ...
# 18         Cooling down with a chance of rain Sunday.
# 19  Similar temperatures continuing with a chance ...
#
#                                                  days alerts  ...  \
# 0   [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 1   [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 2   [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 3   [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 4   [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 5   [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 6   [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 7   [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 8   [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 9   [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 10  [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 11  [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 12  [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 13  [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 14  [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 15  [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 16  [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 17  [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 18  [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
# 19  [{'datetime': '2023-01-13', 'datetimeEpoch': 1...     []  ...
#
#     stations.EPSY.quality  stations.EPSY.contribution  \
# 0                     NaN                         NaN
# 1                     NaN                         NaN
# 2                     NaN                         NaN
# 3                     NaN                         NaN
# 4                     NaN                         NaN
# 5                     NaN                         NaN
# 6                     NaN                         NaN
# 7                     NaN                         NaN
# 8                     NaN                         NaN
# 9                     NaN                         NaN
# 10                    NaN                         NaN
# 11                    NaN                         NaN
# 12                    NaN                         NaN
# 13                    NaN                         NaN
# 14                    NaN                         NaN
# 15                    NaN                         NaN
# 16                    NaN                         NaN
# 17                    NaN                         NaN
# 18                    NaN                         NaN
# 19                   50.0                         0.0
#
#     stations.AV618.distance  stations.AV618.latitude stations.AV618.longitude  \
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
# 2                       NaN                      NaN                      NaN
# 3                       NaN                      NaN                      NaN
# 4                       NaN                      NaN                      NaN
# 5                       NaN                      NaN                      NaN
# 6                       NaN                      NaN                      NaN
# 7                       NaN                      NaN                      NaN
# 8                       NaN                      NaN                      NaN
# 9                       NaN                      NaN                      NaN
# 10                      NaN                      NaN                      NaN
# 11                      NaN                      NaN                      NaN
# 12                      NaN                      NaN                      NaN
# 13                      NaN                      NaN                      NaN
# 14                      NaN                      NaN                      NaN
# 15                      NaN                      NaN                      NaN
# 16                      NaN                      NaN                      NaN
# 17                      NaN                      NaN                      NaN
# 18                      NaN                      NaN                      NaN
# 19                  56842.0                   52.777                   21.538
#
#    stations.AV618.useCount  stations.AV618.id  \
# 0                      NaN                NaN
# 1                      NaN                NaN
# 2                      NaN                NaN
# 3                      NaN                NaN
# 4                      NaN                NaN
# 5                      NaN                NaN
# 6                      NaN                NaN
# 7                      NaN                NaN
# 8                      NaN                NaN
# 9                      NaN                NaN
# 10                     NaN                NaN
# 11                     NaN                NaN
# 12                     NaN                NaN
# 13                     NaN                NaN
# 14                     NaN                NaN
# 15                     NaN                NaN
# 16                     NaN                NaN
# 17                     NaN                NaN
# 18                     NaN                NaN
# 19                     0.0              AV618
#
#                 stations.AV618.name  stations.AV618.quality  \
# 0                               NaN                     NaN
# 1                               NaN                     NaN
# 2                               NaN                     NaN
# 3                               NaN                     NaN
# 4                               NaN                     NaN
# 5                               NaN                     NaN
# 6                               NaN                     NaN
# 7                               NaN                     NaN
# 8                               NaN                     NaN
# 9                               NaN                     NaN
# 10                              NaN                     NaN
# 11                              NaN                     NaN
# 12                              NaN                     NaN
# 13                              NaN                     NaN
# 14                              NaN                     NaN
# 15                              NaN                     NaN
# 16                              NaN                     NaN
# 17                              NaN                     NaN
# 18                              NaN                     NaN
# 19  SQ5VCO-13 Chrzczanka-Folwark PL                     0.0
#
#     stations.AV618.contribution
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          0.0
#
# [20 rows x 352 columns]

# %%
df2 = df['days'][0]
df['days'][0][10]
#df['stations.E5546.latitude']
df_7days = df2[1:8]

# %%
len(df_7days)
# Out:
# 7

# %%
for i in df_7days:
    print(i['datetime'])
# Out:
# 2023-01-14
# 2023-01-15
# 2023-01-16
# 2023-01-17
# 2023-01-18
# 2023-01-19
# 2023-01-20

# %%
#df['days'][0][0]['datetime']
df['days'][0][0]
# Out:
# {'datetime': '2023-01-13',
#  'datetimeEpoch': 1673564400,
#  'tempmax': 6.0,
#  'tempmin': 1.4,
#  'temp': 3.9,
#  'feelslikemax': 5.0,
#  'feelslikemin': -2.5,
#  'feelslike': 1.1,
#  'dew': 2.2,
#  'humidity': 87.4,
#  'precip': 1.0,
#  'precipprob': 100.0,
#  'precipcover': 16.67,
#  'preciptype': ['rain', 'snow'],
#  'snow': 0.0,
#  'snowdepth': 0.0,
#  'windgust': 31.0,
#  'windspeed': 22.7,
#  'winddir': 195.5,
#  'pressure': 1012.8,
#  'cloudcover': 94.4,
#  'visibility': 14.8,
#  'solarradiation': 13.0,
#  'solarenergy': 1.2,
#  'uvindex': 1.0,
#  'severerisk': 10.0,
#  'sunrise': '07:30:48',
#  'sunriseEpoch': 1673591448,
#  'sunset': '15:41:52',
#  'sunsetEpoch': 1673620912,
#  'moonphase': 0.68,
#  'conditions': 'Snow, Rain, Overcast',
#  'description': 'Cloudy skies throughout the day with rain or snow.',
#  'icon': 'rain',
#  'stations': ['remote', 'UMBB'],
#  'source': 'comb',
#  'hours': [{'datetime': '00:00:00',
#    'datetimeEpoch': 1673564400,
#    'temp': 2.2,
#    'feelslike': -1.8,
#    'humidity': 93.1,
#    'dew': 1.2,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'snow': 0.0,
#    'snowdepth': 0.2,
#    'preciptype': None,
#    'windgust': 25.9,
#    'windspeed': 15.1,
#    'winddir': 202.0,
#    'pressure': 1015.0,
#    'visibility': 24.1,
#    'cloudcover': 97.8,
#    'solarradiation': 0.0,
#    'solarenergy': None,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['remote'],
#    'source': 'obs'},
#   {'datetime': '01:00:00',
#    'datetimeEpoch': 1673568000,
#    'temp': 2.3,
#    'feelslike': -1.6,
#    'humidity': 93.1,
#    'dew': 1.3,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': None,
#    'windgust': 23.8,
#    'windspeed': 14.8,
#    'winddir': 204.3,
#    'pressure': 1015.0,
#    'visibility': 24.1,
#    'cloudcover': 90.8,
#    'solarradiation': 0.0,
#    'solarenergy': None,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['remote'],
#    'source': 'obs'},
#   {'datetime': '02:00:00',
#    'datetimeEpoch': 1673571600,
#    'temp': 3.3,
#    'feelslike': -0.2,
#    'humidity': 84.88,
#    'dew': 1.0,
#    'precip': 0.1,
#    'precipprob': 100.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': ['rain'],
#    'windgust': 24.5,
#    'windspeed': 14.0,
#    'winddir': 205.9,
#    'pressure': 1014.0,
#    'visibility': 24.1,
#    'cloudcover': 99.1,
#    'solarradiation': 0.0,
#    'solarenergy': None,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['remote'],
#    'source': 'obs'},
#   {'datetime': '03:00:00',
#    'datetimeEpoch': 1673575200,
#    'temp': 1.4,
#    'feelslike': -2.5,
#    'humidity': 100.0,
#    'dew': 1.6,
#    'precip': 0.1,
#    'precipprob': 100.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': ['rain', 'snow'],
#    'windgust': 25.2,
#    'windspeed': 13.7,
#    'winddir': 208.2,
#    'pressure': 1013.0,
#    'visibility': 24.1,
#    'cloudcover': 93.8,
#    'solarradiation': 0.0,
#    'solarenergy': None,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Snow, Rain, Overcast',
#    'icon': 'rain',
#    'stations': ['remote'],
#    'source': 'obs'},
#   {'datetime': '04:00:00',
#    'datetimeEpoch': 1673578800,
#    'temp': 3.2,
#    'feelslike': -0.1,
#    'humidity': 88.6,
#    'dew': 1.5,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': None,
#    'windgust': 26.3,
#    'windspeed': 12.6,
#    'winddir': 205.6,
#    'pressure': 1014.0,
#    'visibility': 24.1,
#    'cloudcover': 95.2,
#    'solarradiation': 0.0,
#    'solarenergy': None,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['remote'],
#    'source': 'obs'},
#   {'datetime': '05:00:00',
#    'datetimeEpoch': 1673582400,
#    'temp': 2.0,
#    'feelslike': -1.9,
#    'humidity': 93.08,
#    'dew': 1.0,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': None,
#    'windgust': 27.0,
#    'windspeed': 14.4,
#    'winddir': 180.0,
#    'pressure': 1013.0,
#    'visibility': 5.0,
#    'cloudcover': 79.5,
#    'solarradiation': 0.0,
#    'solarenergy': None,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-night',
#    'stations': ['UMBB'],
#    'source': 'obs'},
#   {'datetime': '06:00:00',
#    'datetimeEpoch': 1673586000,
#    'temp': 2.0,
#    'feelslike': -1.9,
#    'humidity': 93.08,
#    'dew': 1.0,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': None,
#    'windgust': 26.6,
#    'windspeed': 14.4,
#    'winddir': 190.0,
#    'pressure': 1013.0,
#    'visibility': 5.0,
#    'cloudcover': 94.2,
#    'solarradiation': 0.0,
#    'solarenergy': None,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['UMBB'],
#    'source': 'obs'},
#   {'datetime': '07:00:00',
#    'datetimeEpoch': 1673589600,
#    'temp': 2.0,
#    'feelslike': -1.9,
#    'humidity': 100.0,
#    'dew': 2.0,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': None,
#    'windgust': 27.7,
#    'windspeed': 14.4,
#    'winddir': 190.0,
#    'pressure': 1013.0,
#    'visibility': 5.0,
#    'cloudcover': 50.0,
#    'solarradiation': 0.0,
#    'solarenergy': None,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-night',
#    'stations': ['UMBB'],
#    'source': 'obs'},
#   {'datetime': '08:00:00',
#    'datetimeEpoch': 1673593200,
#    'temp': 3.0,
#    'feelslike': -0.7,
#    'humidity': 93.14,
#    'dew': 2.0,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': None,
#    'windgust': 25.2,
#    'windspeed': 14.4,
#    'winddir': 180.0,
#    'pressure': 1013.0,
#    'visibility': 5.0,
#    'cloudcover': 88.0,
#    'solarradiation': 1.0,
#    'solarenergy': 0.0,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['UMBB'],
#    'source': 'obs'},
#   {'datetime': '09:00:00',
#    'datetimeEpoch': 1673596800,
#    'temp': 3.0,
#    'feelslike': -0.7,
#    'humidity': 93.14,
#    'dew': 2.0,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': None,
#    'windgust': 25.2,
#    'windspeed': 14.4,
#    'winddir': 190.0,
#    'pressure': 1013.0,
#    'visibility': 5.0,
#    'cloudcover': 100.0,
#    'solarradiation': 4.0,
#    'solarenergy': 0.0,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['UMBB'],
#    'source': 'obs'},
#   {'datetime': '10:00:00',
#    'datetimeEpoch': 1673600400,
#    'temp': 4.0,
#    'feelslike': 0.6,
#    'humidity': 86.8,
#    'dew': 2.0,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': None,
#    'windgust': 25.2,
#    'windspeed': 14.4,
#    'winddir': 200.0,
#    'pressure': 1013.0,
#    'visibility': 6.0,
#    'cloudcover': 100.0,
#    'solarradiation': 9.0,
#    'solarenergy': 0.0,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['UMBB'],
#    'source': 'obs'},
#   {'datetime': '11:00:00',
#    'datetimeEpoch': 1673604000,
#    'temp': 5.0,
#    'feelslike': 1.3,
#    'humidity': 80.94,
#    'dew': 2.0,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': None,
#    'windgust': 28.8,
#    'windspeed': 18.0,
#    'winddir': 190.0,
#    'pressure': 1013.0,
#    'visibility': 6.0,
#    'cloudcover': 100.0,
#    'solarradiation': 15.0,
#    'solarenergy': 0.1,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['UMBB'],
#    'source': 'obs'},
#   {'datetime': '12:00:00',
#    'datetimeEpoch': 1673607600,
#    'temp': 5.0,
#    'feelslike': 1.8,
#    'humidity': 80.94,
#    'dew': 2.0,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': None,
#    'windgust': 29.2,
#    'windspeed': 14.4,
#    'winddir': 200.0,
#    'pressure': 1012.0,
#    'visibility': 6.0,
#    'cloudcover': 100.0,
#    'solarradiation': 126.0,
#    'solarenergy': 0.5,
#    'uvindex': 1.0,
#    'severerisk': 10.0,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['UMBB'],
#    'source': 'obs'},
#   {'datetime': '13:00:00',
#    'datetimeEpoch': 1673611200,
#    'temp': 5.0,
#    'feelslike': 2.4,
#    'humidity': 80.94,
#    'dew': 2.0,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': None,
#    'windgust': 31.0,
#    'windspeed': 10.8,
#    'winddir': 180.0,
#    'pressure': 1012.0,
#    'visibility': 6.0,
#    'cloudcover': 88.0,
#    'solarradiation': 73.0,
#    'solarenergy': 0.3,
#    'uvindex': 1.0,
#    'severerisk': 10.0,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['UMBB'],
#    'source': 'obs'},
#   {'datetime': '14:00:00',
#    'datetimeEpoch': 1673614800,
#    'temp': 6.0,
#    'feelslike': 3.0,
#    'humidity': 75.51,
#    'dew': 2.0,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': None,
#    'windgust': 29.9,
#    'windspeed': 14.4,
#    'winddir': 180.0,
#    'pressure': 1012.0,
#    'visibility': 6.0,
#    'cloudcover': 100.0,
#    'solarradiation': 46.0,
#    'solarenergy': 0.2,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['UMBB'],
#    'source': 'obs'},
#   {'datetime': '15:00:00',
#    'datetimeEpoch': 1673618400,
#    'temp': 5.0,
#    'feelslike': 1.8,
#    'humidity': 80.94,
#    'dew': 2.0,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': None,
#    'windgust': 28.8,
#    'windspeed': 14.4,
#    'winddir': 160.0,
#    'pressure': 1012.0,
#    'visibility': 6.0,
#    'cloudcover': 88.0,
#    'solarradiation': 36.0,
#    'solarenergy': 0.1,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Partially cloudy',
#    'icon': 'partly-cloudy-day',
#    'stations': ['UMBB'],
#    'source': 'obs'},
#   {'datetime': '16:00:00',
#    'datetimeEpoch': 1673622000,
#    'temp': 5.4,
#    'feelslike': 2.4,
#    'humidity': 83.92,
#    'dew': 2.9,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': None,
#    'windgust': 25.6,
#    'windspeed': 13.7,
#    'winddir': 183.4,
#    'pressure': 1011.0,
#    'visibility': 24.1,
#    'cloudcover': 100.0,
#    'solarradiation': 1.0,
#    'solarenergy': 0.0,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': ['remote'],
#    'source': 'obs'},
#   {'datetime': '17:00:00',
#    'datetimeEpoch': 1673625600,
#    'temp': 5.0,
#    'feelslike': 5.0,
#    'humidity': 77.71,
#    'dew': 2.5,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': None,
#    'windgust': 24.3,
#    'windspeed': 20.9,
#    'winddir': 199.4,
#    'pressure': 1011.5,
#    'visibility': 24.1,
#    'cloudcover': 100.0,
#    'solarradiation': 0.0,
#    'solarenergy': None,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': None,
#    'source': 'fcst'},
#   {'datetime': '18:00:00',
#    'datetimeEpoch': 1673629200,
#    'temp': 4.6,
#    'feelslike': 4.6,
#    'humidity': 77.71,
#    'dew': 2.5,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': None,
#    'windgust': 23.0,
#    'windspeed': 20.5,
#    'winddir': 199.4,
#    'pressure': 1012.0,
#    'visibility': 24.1,
#    'cloudcover': 100.0,
#    'solarradiation': 0.0,
#    'solarenergy': None,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': None,
#    'source': 'fcst'},
#   {'datetime': '19:00:00',
#    'datetimeEpoch': 1673632800,
#    'temp': 5.0,
#    'feelslike': 1.7,
#    'humidity': 89.39,
#    'dew': 3.4,
#    'precip': 0.0,
#    'precipprob': 0.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': None,
#    'windgust': 26.6,
#    'windspeed': 15.1,
#    'winddir': 191.7,
#    'pressure': 1013.0,
#    'visibility': 24.1,
#    'cloudcover': 100.0,
#    'solarradiation': 0.0,
#    'solarenergy': None,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Overcast',
#    'icon': 'cloudy',
#    'stations': None,
#    'source': 'fcst'},
#   {'datetime': '20:00:00',
#    'datetimeEpoch': 1673636400,
#    'temp': 4.7,
#    'feelslike': 4.7,
#    'humidity': 82.79,
#    'dew': 3.1,
#    'precip': 0.0,
#    'precipprob': 100.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': ['rain'],
#    'windgust': 26.3,
#    'windspeed': 22.0,
#    'winddir': 205.0,
#    'pressure': 1012.5,
#    'visibility': 24.1,
#    'cloudcover': 100.0,
#    'solarradiation': 0.0,
#    'solarenergy': None,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': None,
#    'source': 'fcst'},
#   {'datetime': '21:00:00',
#    'datetimeEpoch': 1673640000,
#    'temp': 4.5,
#    'feelslike': 4.5,
#    'humidity': 90.05,
#    'dew': 3.9,
#    'precip': 0.6,
#    'precipprob': 100.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': ['rain'],
#    'windgust': 25.9,
#    'windspeed': 22.0,
#    'winddir': 203.9,
#    'pressure': 1012.0,
#    'visibility': 15.4,
#    'cloudcover': 100.0,
#    'solarradiation': 0.0,
#    'solarenergy': None,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': None,
#    'source': 'fcst'},
#   {'datetime': '22:00:00',
#    'datetimeEpoch': 1673643600,
#    'temp': 4.8,
#    'feelslike': 1.7,
#    'humidity': 92.58,
#    'dew': 3.7,
#    'precip': 0.2,
#    'precipprob': 100.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': ['rain'],
#    'windgust': 27.4,
#    'windspeed': 13.3,
#    'winddir': 206.0,
#    'pressure': 1012.0,
#    'visibility': 24.1,
#    'cloudcover': 100.0,
#    'solarradiation': 0.0,
#    'solarenergy': None,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': None,
#    'source': 'fcst'},
#   {'datetime': '23:00:00',
#    'datetimeEpoch': 1673647200,
#    'temp': 4.8,
#    'feelslike': 4.8,
#    'humidity': 86.35,
#    'dew': 3.5,
#    'precip': 0.0,
#    'precipprob': 100.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'preciptype': ['rain'],
#    'windgust': 28.3,
#    'windspeed': 22.7,
#    'winddir': 212.3,
#    'pressure': 1013.0,
#    'visibility': 14.6,
#    'cloudcover': 100.0,
#    'solarradiation': 0.0,
#    'solarenergy': None,
#    'uvindex': 0.0,
#    'severerisk': 10.0,
#    'conditions': 'Rain, Overcast',
#    'icon': 'rain',
#    'stations': None,
#    'source': 'fcst'}]}

# %%
df_data = pd.DataFrame([[df['days'][0][0]['datetime'], df['address'], ]], columns=['date', 'city'])
df_data
# Out:
#          date                                               city
# 0  2023-01-13  0          Biała Podlaska
# 1               Biał...

# %%
df['days'][0][1]['datetime']
# Out:
# '2023-01-14'

# %%
df['address']
# Out:
# 0          Biała Podlaska
# 1               Białystok
# 2           Bielsko-Biała
# 3               Bydgoszcz
# 4                  Gdańsk
# 5     Gorzów Wielkopolski
# 6                  Kalisz
# 7                Katowice
# 8                Koszalin
# 9                  Kraków
# 10                 Lublin
# 11                 Poznań
# 12                  Radom
# 13                Rzeszów
# 14                Suwałki
# 15               Szczecin
# 16             Szczecinek
# 17               Warszawa
# 18                Wrocław
# 19                  Łomża
# Name: address, dtype: object

# %%
df_data = pd.DataFrame([[df['days'][0][0]['datetime'], df['address'][0], df['days'][0][0]['tempmax'], df['days'][0][0]['tempmin'], 
       df['days'][0][0]['temp'], df['days'][0][0]['feelslikemax'], df['days'][0][0]['feelslikemax'], df['days'][0][0]['feelslike'],
       df['days'][0][0]['dew'], df['days'][0][0]['humidity'], df['days'][0][0]['precip'], df['days'][0][0]['precipprob'],
       df['days'][0][0]['precipcover'], df['days'][0][0]['snow'], df['days'][0][0]['snowdepth'], df['days'][0][0]['windgust'], 
       df['days'][0][0]['windspeed'], df['days'][0][0]['winddir'], df['days'][0][0]['cloudcover'], df['days'][0][0]['visibility'], 
       df['days'][0][0]['solarradiation'], df['days'][0][0]['solarenergy'], df['days'][0][0]['uvindex'], df['days'][0][0]['conditions']]],
       #df['days'][0][0][''], df['days'][0][0][''], df['days'][0][0][''], df['days'][0][0][''], 
       columns=['date', 'city', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
              'feelslikemin', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob',
              'precipcover', 'snow', 'snowdepth', 'windgust', 'windspeed', 'winddir',
              'cloudcover', 'visibility', 'solarradiation', 'solarenergy', 'uvindex',
              'conditions'])#, 'area', 'density', 'no_people'])

df_data

df_temp = pd.DataFrame()
for i in range(0, len(df)):
       for k in range(0, 7):
              if not (i == 0 and k == 0):
                     df_temp = pd.DataFrame([[df['days'][i][k]['datetime'], df['address'][i], df['days'][i][k]['tempmax'], df['days'][i][k]['tempmin'], 
                     df['days'][i][k]['temp'], df['days'][i][k]['feelslikemax'], df['days'][i][k]['feelslikemax'], df['days'][i][k]['feelslike'],
                     df['days'][i][k]['dew'], df['days'][i][k]['humidity'], df['days'][i][k]['precip'], df['days'][i][k]['precipprob'],
                     df['days'][i][k]['precipcover'], df['days'][i][k]['snow'], df['days'][i][k]['snowdepth'], df['days'][i][k]['windgust'], 
                     df['days'][i][k]['windspeed'], df['days'][i][k]['winddir'], df['days'][i][k]['cloudcover'], df['days'][i][k]['visibility'], 
                     df['days'][i][k]['solarradiation'], df['days'][i][k]['solarenergy'], df['days'][i][k]['uvindex'], df['days'][i][k]['conditions']]],
                     #df['days'][0][0][''], df['days'][0][0][''], df['days'][0][0][''], df['days'][0][0][''], 
                     columns=['date', 'city', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
                            'feelslikemin', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob',
                            'precipcover', 'snow', 'snowdepth', 'windgust', 'windspeed', 'winddir',
                            'cloudcover', 'visibility', 'solarradiation', 'solarenergy', 'uvindex',
                            'conditions'])#, 'area', 'density', 'no_people'])
                     
              df_data = pd.concat([df_data, df_temp], ignore_index=True)

df_data
# Out:
#            date            city  tempmax  tempmin  temp  feelslikemax  \
# 0    2023-01-13  Biała Podlaska      6.0      1.4   3.9           5.0
# 1    2023-01-14  Biała Podlaska      6.5      2.3   4.2           5.9
# 2    2023-01-15  Biała Podlaska      5.1      1.7   3.7           4.3
# 3    2023-01-16  Biała Podlaska      5.0      2.3   3.6           3.6
# 4    2023-01-17  Biała Podlaska      5.4      2.9   4.2           1.9
# ..          ...             ...      ...      ...   ...           ...
# 135  2023-01-15           Łomża      4.9      2.5   4.2           4.9
# 136  2023-01-16           Łomża      3.8      0.7   2.4           3.7
# 137  2023-01-17           Łomża      5.1      2.0   3.6           1.2
# 138  2023-01-18           Łomża      8.8      2.0   4.5           4.8
# 139  2023-01-19           Łomża      2.8     -0.3   1.1          -2.7
#
#      feelslikemin  feelslike  dew  humidity  ...  snowdepth  windgust  \
# 0             5.0        1.1  2.2      87.4  ...        0.0      31.0
# 1             5.9        3.3  2.7      86.5  ...        0.0      47.5
# 2             4.3        3.1  1.4      81.1  ...        0.0      63.4
# 3             3.6        0.0  1.1      83.8  ...        0.0      46.1
# 4             1.9        0.0  1.5      82.7  ...        0.0      51.8
# ..            ...        ...  ...       ...  ...        ...       ...
# 135           4.9        3.5  2.2      83.4  ...        0.0      66.2
# 136           3.7       -1.6 -0.7      79.6  ...        0.0      49.0
# 137           1.2       -0.9  1.9      88.8  ...        0.0      52.9
# 138           4.8       -0.1  1.8      82.7  ...        0.0      59.8
# 139          -2.7       -4.4 -5.1      63.9  ...        0.0      50.8
#
#      windspeed  winddir  cloudcover  visibility  solarradiation  solarenergy  \
# 0         22.7    195.5        94.4        14.8            13.0          1.2
# 1         21.6    216.0        86.0        24.1            11.4          1.0
# 2         33.5    202.1        97.4        23.3             7.0          0.5
# 3         23.4    176.1        95.6        19.1            49.8          4.1
# 4         28.4    143.7        94.3        22.3            19.8          1.8
# ..         ...      ...         ...         ...             ...          ...
# 135       38.2    205.7        95.8        19.6             1.5          0.0
# 136       25.6    193.3        76.4        23.1            46.1          4.0
# 137       28.1    137.3        98.5        18.0            12.5          1.1
# 138       35.6    170.6        99.1        21.8            10.0          0.9
# 139       31.6    211.0        40.0        24.1            51.3          4.7
#
#      uvindex                    conditions
# 0        1.0          Snow, Rain, Overcast
# 1        0.0        Rain, Partially cloudy
# 2        1.0                Rain, Overcast
# 3        3.0                Rain, Overcast
# 4        1.0                Rain, Overcast
# ..       ...                           ...
# 135      0.0                Rain, Overcast
# 136      2.0        Rain, Partially cloudy
# 137      1.0          Snow, Rain, Overcast
# 138      1.0          Snow, Rain, Overcast
# 139      2.0  Snow, Rain, Partially cloudy
#
# [140 rows x 24 columns]

# %%
df_data['city'] = df_data['city'].str.lower()
df_data['conditions'] = df_data['conditions'].str.lower()
df_data
# Out:
#            date            city  tempmax  tempmin  temp  feelslikemax  \
# 0    2023-01-13  biała podlaska      6.0      1.4   3.9           5.0
# 1    2023-01-14  biała podlaska      6.5      2.3   4.2           5.9
# 2    2023-01-15  biała podlaska      5.1      1.7   3.7           4.3
# 3    2023-01-16  biała podlaska      5.0      2.3   3.6           3.6
# 4    2023-01-17  biała podlaska      5.4      2.9   4.2           1.9
# ..          ...             ...      ...      ...   ...           ...
# 135  2023-01-15           łomża      4.9      2.5   4.2           4.9
# 136  2023-01-16           łomża      3.8      0.7   2.4           3.7
# 137  2023-01-17           łomża      5.1      2.0   3.6           1.2
# 138  2023-01-18           łomża      8.8      2.0   4.5           4.8
# 139  2023-01-19           łomża      2.8     -0.3   1.1          -2.7
#
#      feelslikemin  feelslike  dew  humidity  ...  snowdepth  windgust  \
# 0             5.0        1.1  2.2      87.4  ...        0.0      31.0
# 1             5.9        3.3  2.7      86.5  ...        0.0      47.5
# 2             4.3        3.1  1.4      81.1  ...        0.0      63.4
# 3             3.6        0.0  1.1      83.8  ...        0.0      46.1
# 4             1.9        0.0  1.5      82.7  ...        0.0      51.8
# ..            ...        ...  ...       ...  ...        ...       ...
# 135           4.9        3.5  2.2      83.4  ...        0.0      66.2
# 136           3.7       -1.6 -0.7      79.6  ...        0.0      49.0
# 137           1.2       -0.9  1.9      88.8  ...        0.0      52.9
# 138           4.8       -0.1  1.8      82.7  ...        0.0      59.8
# 139          -2.7       -4.4 -5.1      63.9  ...        0.0      50.8
#
#      windspeed  winddir  cloudcover  visibility  solarradiation  solarenergy  \
# 0         22.7    195.5        94.4        14.8            13.0          1.2
# 1         21.6    216.0        86.0        24.1            11.4          1.0
# 2         33.5    202.1        97.4        23.3             7.0          0.5
# 3         23.4    176.1        95.6        19.1            49.8          4.1
# 4         28.4    143.7        94.3        22.3            19.8          1.8
# ..         ...      ...         ...         ...             ...          ...
# 135       38.2    205.7        95.8        19.6             1.5          0.0
# 136       25.6    193.3        76.4        23.1            46.1          4.0
# 137       28.1    137.3        98.5        18.0            12.5          1.1
# 138       35.6    170.6        99.1        21.8            10.0          0.9
# 139       31.6    211.0        40.0        24.1            51.3          4.7
#
#      uvindex                    conditions
# 0        1.0          snow, rain, overcast
# 1        0.0        rain, partially cloudy
# 2        1.0                rain, overcast
# 3        3.0                rain, overcast
# 4        1.0                rain, overcast
# ..       ...                           ...
# 135      0.0                rain, overcast
# 136      2.0        rain, partially cloudy
# 137      1.0          snow, rain, overcast
# 138      1.0          snow, rain, overcast
# 139      2.0  snow, rain, partially cloudy
#
# [140 rows x 24 columns]

# %%
df_meta['city'] = df_meta['city'].str.lower()
df_meta_temp = df_meta
df_meta_temp.drop(columns='city_id')
df_meta_temp
# Out:
#            city_id                 city        lon         lat    area  \
# 0   biala_podlaska       biała podlaska  52.033333   23.116667   49.40
# 1        bialystok            białystok  53.135278   23.145556  102.13
# 2    bielsko_biala        bielsko-biała  49.822500   19.044444  124.51
# 3        bydgoszcz            bydgoszcz  53.125000   18.011111  175.98
# 4           gdansk               gdańsk  54.347500   18.645278  263.44
# 5           gorzow  gorzów wielkopolski  52.730833   15.238333   85.72
# 6           kalisz               kalisz  51.762500   18.089722   69.42
# 7         katowice             katowice  50.264167   19.023611  164.64
# 8         koszalin             koszalin  54.190278   16.181667   98.34
# 9           krakow               kraków  50.061389   19.938333  326.85
# 10          lublin               lublin  51.250000   22.566667  147.45
# 11          poznan               poznań  52.408333   16.934167  261.91
# 12           radom                radom  51.403611   21.156667  111.80
# 13         rzeszow              rzeszów  50.033611   22.004722  129.01
# 14         suwalki              suwałki  54.101111     22.9325   65.50
# 15        szczecin             szczecin  53.438056   14.542222  300.55
# 16      szczecinek           szczecinek  53.720833   16.686111   48.48
# 17        warszawa             warszawa  52.232222   21.008333  512.24
# 18         wroclaw              wrocław  51.110000   17.022222  292.82
# 19            lodz                 łódź  51.776667   19.454722  293.25
# 20           lomza                łomża  53.176389   22.073056   32.67
#
#     density  no_people
# 0   1152.06      56942
# 1   2872.90     293413
# 2   1351.90     168319
# 3   1941.70     337666
# 4   1845.00     486022
# 5   1369.30     117379
# 6   1427.60      99106
# 7   1742.90     286960
# 8   1075.90     105801
# 9   2455.50     802583
# 10  2269.80     334681
# 11  2031.40     546859
# 12  1872.10     209296
# 13  1539.00     198609
# 14  1062.10      69575
# 15  1319.20     396472
# 16   819.00      39705
# 17  3597.00    1860281
# 18  2298.00     672929
# 19  2287.00     670642
# 20  1915.30      62573

# %%
df_data = df_data.join(df_meta_temp.set_index('city'), on='city')

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

scaler = StandardScaler()

cols = ['tempmax', 'tempmin', 'temp', 'feelslikemax',
       'feelslikemin', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob',
       'precipcover', 'snow', 'snowdepth', 'windgust', 'windspeed', 'winddir',
       'cloudcover', 'visibility', 'solarradiation', 'solarenergy', 'uvindex']

le = LabelEncoder()
df_data['conditions'] = le.fit_transform(df_data['conditions'])

df_data[cols] = scaler.fit_transform(df_data[cols])
df_data
# Out:
#            date            city   tempmax   tempmin      temp  feelslikemax  \
# 0    2023-01-13  biała podlaska  0.276841 -0.187344  0.141378      0.439827
# 1    2023-01-14  biała podlaska  0.490736  0.257201  0.283774      0.717334
# 2    2023-01-15  biała podlaska -0.108170 -0.039162  0.046448      0.223988
# 3    2023-01-16  biała podlaska -0.150949  0.257201 -0.001017      0.008149
# 4    2023-01-17  biała podlaska  0.020167  0.553563  0.283774     -0.516031
# ..          ...             ...       ...       ...       ...           ...
# 135  2023-01-15           łomża -0.193728  0.355988  0.283774      0.408993
# 136  2023-01-16           łomża -0.664297 -0.533100 -0.570599      0.038983
# 137  2023-01-17           łomża -0.108170  0.109019 -0.001017     -0.731870
# 138  2023-01-18           łomża  1.474654  0.109019  0.426170      0.378159
# 139  2023-01-19           łomża -1.092087 -1.027038 -1.187647     -1.934401
#
#      feelslikemin  feelslike       dew  humidity  ...  solarradiation  \
# 0        0.439827   0.087806  0.571474  0.794808  ...       -0.662384
# 1        0.717334   0.765608  0.779499  0.670773  ...       -0.755490
# 2        0.223988   0.703990  0.238634 -0.073437  ...       -1.011532
# 3        0.008149  -0.251095  0.113819  0.298668  ...        1.479057
# 4       -0.516031  -0.251095  0.280239  0.147070  ...       -0.266683
# ..            ...        ...       ...       ...  ...             ...
# 135      0.408993   0.827226  0.571474  0.243542  ...       -1.331584
# 136      0.038983  -0.744041 -0.635071 -0.280162  ...        1.263749
# 137     -0.731870  -0.528377  0.446659  0.987752  ...       -0.691479
# 138      0.378159  -0.281904  0.405054  0.147070  ...       -0.836958
# 139     -1.934401  -1.606698 -2.465691 -2.443883  ...        1.566344
#
#      solarenergy   uvindex  conditions         city_id        lon         lat  \
# 0      -0.586620 -0.373310           4  biala_podlaska  52.033333   23.116667
# 1      -0.719404 -1.485297           3  biala_podlaska  52.033333   23.116667
# 2      -1.051364 -0.373310           2  biala_podlaska  52.033333   23.116667
# 3       1.338746  1.850664           2  biala_podlaska  52.033333   23.116667
# 4      -0.188269 -0.373310           2  biala_podlaska  52.033333   23.116667
# ..           ...       ...         ...             ...        ...         ...
# 135    -1.383324 -1.485297           2           lomza  53.176389   22.073056
# 136     1.272354  0.738677           3           lomza  53.176389   22.073056
# 137    -0.653012 -0.373310           4           lomza  53.176389   22.073056
# 138    -0.785796 -0.373310           4           lomza  53.176389   22.073056
# 139     1.737098  0.738677           5           lomza  53.176389   22.073056
#
#       area  density  no_people
# 0    49.40  1152.06      56942
# 1    49.40  1152.06      56942
# 2    49.40  1152.06      56942
# 3    49.40  1152.06      56942
# 4    49.40  1152.06      56942
# ..     ...      ...        ...
# 135  32.67  1915.30      62573
# 136  32.67  1915.30      62573
# 137  32.67  1915.30      62573
# 138  32.67  1915.30      62573
# 139  32.67  1915.30      62573
#
# [140 rows x 30 columns]

# %%
df_data['city'].unique()
# Out:
# array(['biała podlaska', 'białystok', 'bielsko-biała', 'bydgoszcz',
#        'gdańsk', 'gorzów wielkopolski', 'kalisz', 'katowice', 'koszalin',
#        'kraków', 'lublin', 'poznań', 'radom', 'rzeszów', 'suwałki',
#        'szczecin', 'szczecinek', 'warszawa', 'wrocław', 'łomża'],
#       dtype=object)

# %%
df_data.to_csv('test_data.csv', index = False)

# %%
from weather import *

get_weather()
# Out:
# https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Biała Podlaska?unitGroup=metric&key=N2U7NNAJ7SLBWTTG6SRHZ2YNG&contentType=json
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# hello
#            date            city  tempmax  tempmin  temp  feelslikemax  \
# 0    2023-01-13  Biała Podlaska      6.0      1.4   3.9           5.0
# 1    2023-01-14  Biała Podlaska      6.5      2.3   4.2           5.9
# 2    2023-01-15  Biała Podlaska      5.1      1.7   3.7           4.3
# 3    2023-01-16  Biała Podlaska      5.0      2.3   3.6           3.6
# 4    2023-01-17  Biała Podlaska      5.4      2.9   4.2           1.9
# ..          ...             ...      ...      ...   ...           ...
# 135  2023-01-15           Łomża      4.9      2.5   4.2           4.9
# 136  2023-01-16           Łomża      3.8      0.7   2.4           3.7
# 137  2023-01-17           Łomża      5.1      2.0   3.6           1.2
# 138  2023-01-18           Łomża      8.8      2.0   4.5           4.8
# 139  2023-01-19           Łomża      2.8     -0.3   1.1          -2.7
#
#      feelslikemin  feelslike  dew  humidity  ...  snowdepth  windgust  \
# 0             5.0        1.1  2.2      87.4  ...        0.0      31.0
# 1             5.9        3.3  2.7      86.5  ...        0.0      47.5
# 2             4.3        3.1  1.4      81.1  ...        0.0      63.4
# 3             3.6        0.0  1.1      83.8  ...        0.0      46.1
# 4             1.9        0.0  1.5      82.7  ...        0.0      51.8
# ..            ...        ...  ...       ...  ...        ...       ...
# 135           4.9        3.5  2.2      83.4  ...        0.0      66.2
# 136           3.7       -1.6 -0.7      79.6  ...        0.0      49.0
# 137           1.2       -0.9  1.9      88.8  ...        0.0      52.9
# 138           4.8       -0.1  1.8      82.7  ...        0.0      59.8
# 139          -2.7       -4.4 -5.1      63.9  ...        0.0      50.8
#
#      windspeed  winddir  cloudcover  visibility  solarradiation  solarenergy  \
# 0         22.7    195.5        94.4        14.8            13.0          1.2
# 1         21.6    216.0        86.0        24.1            11.4          1.0
# 2         33.5    202.1        97.4        23.3             7.0          0.5
# 3         23.4    176.1        95.6        19.1            49.8          4.1
# 4         28.4    143.7        94.3        22.3            19.8          1.8
# ..         ...      ...         ...         ...             ...          ...
# 135       38.2    205.7        95.8        19.6             1.5          0.0
# 136       25.6    193.3        76.4        23.1            46.1          4.0
# 137       28.1    137.3        98.5        18.0            12.5          1.1
# 138       35.6    170.6        99.1        21.8            10.0          0.9
# 139       31.6    211.0        40.0        24.1            51.3          4.7
#
#      uvindex              conditions
# 0        1.0    Snow, Rain, Overcast
# 1        0.0  Rain, Partially cloudy
# 2        1.0          Rain, Overcast
# 3        3.0          Rain, Overcast
# 4        1.0          Rain, Overcast
# ..       ...                     ...
# 135      0.0          Rain, Overcast
# 136      2.0  Rain, Partially cloudy
# 137      1.0    Snow, Rain, Overcast
# 138      1.0    Snow, Rain, Overcast
# 139      2.0        Partially cloudy
#
# [140 rows x 24 columns]
# hello
# XXX
#            date            city   tempmax   tempmin      temp  feelslikemax  \
# 0    2023-01-13  biała podlaska  0.276841 -0.187344  0.141378      0.439827
# 1    2023-01-14  biała podlaska  0.490736  0.257201  0.283774      0.717334
# 2    2023-01-15  biała podlaska -0.108170 -0.039162  0.046448      0.223988
# 3    2023-01-16  biała podlaska -0.150949  0.257201 -0.001017      0.008149
# 4    2023-01-17  biała podlaska  0.020167  0.553563  0.283774     -0.516031
# ..          ...             ...       ...       ...       ...           ...
# 135  2023-01-15           łomża -0.193728  0.355988  0.283774      0.408993
# 136  2023-01-16           łomża -0.664297 -0.533100 -0.570599      0.038983
# 137  2023-01-17           łomża -0.108170  0.109019 -0.001017     -0.731870
# 138  2023-01-18           łomża  1.474654  0.109019  0.426170      0.378159
# 139  2023-01-19           łomża -1.092087 -1.027038 -1.187647     -1.934401
#
#      feelslikemin  feelslike       dew  humidity  ...  solarradiation  \
# 0        0.439827   0.087806  0.571474  0.794808  ...       -0.663108
# 1        0.717334   0.765608  0.779499  0.670773  ...       -0.756269
# 2        0.223988   0.703990  0.238634 -0.073437  ...       -1.012462
# 3        0.008149  -0.251095  0.113819  0.298668  ...        1.479599
# 4       -0.516031  -0.251095  0.280239  0.147070  ...       -0.267173
# ..            ...        ...       ...       ...  ...             ...
# 135      0.408993   0.827226  0.571474  0.243542  ...       -1.332704
# 136      0.038983  -0.744041 -0.635071 -0.280162  ...        1.264164
# 137     -0.731870  -0.528377  0.446659  0.987752  ...       -0.692221
# 138      0.378159  -0.281904  0.405054  0.147070  ...       -0.837785
# 139     -1.934401  -1.606698 -2.465691 -2.443883  ...        1.566937
#
#      solarenergy   uvindex  conditions         city_id        lon         lat  \
# 0      -0.587471 -0.373310           4  biala_podlaska  52.033333   23.116667
# 1      -0.720340 -1.485297           3  biala_podlaska  52.033333   23.116667
# 2      -1.052512 -0.373310           2  biala_podlaska  52.033333   23.116667
# 3       1.339130  1.850664           2  biala_podlaska  52.033333   23.116667
# 4      -0.188864 -0.373310           2  biala_podlaska  52.033333   23.116667
# ..           ...       ...         ...             ...        ...         ...
# 135    -1.384685 -1.485297           2           lomza  53.176389   22.073056
# 136     1.272695  0.738677           3           lomza  53.176389   22.073056
# 137    -0.653905 -0.373310           4           lomza  53.176389   22.073056
# 138    -0.786774 -0.373310           4           lomza  53.176389   22.073056
# 139     1.737737  0.738677           1           lomza  53.176389   22.073056
#
#       area  density  no_people
# 0    49.40  1152.06      56942
# 1    49.40  1152.06      56942
# 2    49.40  1152.06      56942
# 3    49.40  1152.06      56942
# 4    49.40  1152.06      56942
# ..     ...      ...        ...
# 135  32.67  1915.30      62573
# 136  32.67  1915.30      62573
# 137  32.67  1915.30      62573
# 138  32.67  1915.30      62573
# 139  32.67  1915.30      62573
#
# [140 rows x 30 columns]
# https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Biała Podlaska?unitGroup=metric&key=N2U7NNAJ7SLBWTTG6SRHZ2YNG&contentType=json
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# successful fetch
# hello
#            date            city  tempmax  tempmin  temp  feelslikemax  \
# 0    2023-01-13  Biała Podlaska      6.0      1.4   3.9           5.0
# 1    2023-01-14  Biała Podlaska      6.5      2.3   4.2           5.9
# 2    2023-01-15  Biała Podlaska      5.1      1.7   3.7           4.3
# 3    2023-01-16  Biała Podlaska      5.0      2.3   3.6           3.6
# 4    2023-01-17  Biała Podlaska      5.4      2.9   4.2           1.9
# ..          ...             ...      ...      ...   ...           ...
# 135  2023-01-15           Łomża      4.9      2.5   4.2           4.9
# 136  2023-01-16           Łomża      3.8      0.7   2.4           3.7
# 137  2023-01-17           Łomża      5.1      2.0   3.6           1.2
# 138  2023-01-18           Łomża      8.8      2.0   4.5           4.8
# 139  2023-01-19           Łomża      2.8     -0.3   1.1          -2.7
#
#      feelslikemin  feelslike  dew  humidity  ...  snowdepth  windgust  \
# 0             5.0        1.1  2.2      87.4  ...        0.0      31.0
# 1             5.9        3.3  2.7      86.5  ...        0.0      47.5
# 2             4.3        3.1  1.4      81.1  ...        0.0      63.4
# 3             3.6        0.0  1.1      83.8  ...        0.0      46.1
# 4             1.9        0.0  1.5      82.7  ...        0.0      51.8
# ..            ...        ...  ...       ...  ...        ...       ...
# 135           4.9        3.5  2.2      83.4  ...        0.0      66.2
# 136           3.7       -1.6 -0.7      79.6  ...        0.0      49.0
# 137           1.2       -0.9  1.9      88.8  ...        0.0      52.9
# 138           4.8       -0.1  1.8      82.7  ...        0.0      59.8
# 139          -2.7       -4.4 -5.1      63.9  ...        0.0      50.8
#
#      windspeed  winddir  cloudcover  visibility  solarradiation  solarenergy  \
# 0         22.7    195.5        94.4        14.8            13.0          1.2
# 1         21.6    216.0        86.0        24.1            11.4          1.0
# 2         33.5    202.1        97.4        23.3             7.0          0.5
# 3         23.4    176.1        95.6        19.1            49.8          4.1
# 4         28.4    143.7        94.3        22.3            19.8          1.8
# ..         ...      ...         ...         ...             ...          ...
# 135       38.2    205.7        95.8        19.6             1.5          0.0
# 136       25.6    193.3        76.4        23.1            46.1          4.0
# 137       28.1    137.3        98.5        18.0            12.5          1.1
# 138       35.6    170.6        99.1        21.8            10.0          0.9
# 139       31.6    211.0        40.0        24.1            51.3          4.7
#
#      uvindex              conditions
# 0        1.0    Snow, Rain, Overcast
# 1        0.0  Rain, Partially cloudy
# 2        1.0          Rain, Overcast
# 3        3.0          Rain, Overcast
# 4        1.0          Rain, Overcast
# ..       ...                     ...
# 135      0.0          Rain, Overcast
# 136      2.0  Rain, Partially cloudy
# 137      1.0    Snow, Rain, Overcast
# 138      1.0    Snow, Rain, Overcast
# 139      2.0        Partially cloudy
#
# [140 rows x 24 columns]
# hello
# XXX
#            date            city   tempmax   tempmin      temp  feelslikemax  \
# 0    2023-01-13  biała podlaska  0.276841 -0.187344  0.141378      0.439827
# 1    2023-01-14  biała podlaska  0.490736  0.257201  0.283774      0.717334
# 2    2023-01-15  biała podlaska -0.108170 -0.039162  0.046448      0.223988
# 3    2023-01-16  biała podlaska -0.150949  0.257201 -0.001017      0.008149
# 4    2023-01-17  biała podlaska  0.020167  0.553563  0.283774     -0.516031
# ..          ...             ...       ...       ...       ...           ...
# 135  2023-01-15           łomża -0.193728  0.355988  0.283774      0.408993
# 136  2023-01-16           łomża -0.664297 -0.533100 -0.570599      0.038983
# 137  2023-01-17           łomża -0.108170  0.109019 -0.001017     -0.731870
# 138  2023-01-18           łomża  1.474654  0.109019  0.426170      0.378159
# 139  2023-01-19           łomża -1.092087 -1.027038 -1.187647     -1.934401
#
#      feelslikemin  feelslike       dew  humidity  ...  solarradiation  \
# 0        0.439827   0.087806  0.571474  0.794808  ...       -0.663108
# 1        0.717334   0.765608  0.779499  0.670773  ...       -0.756269
# 2        0.223988   0.703990  0.238634 -0.073437  ...       -1.012462
# 3        0.008149  -0.251095  0.113819  0.298668  ...        1.479599
# 4       -0.516031  -0.251095  0.280239  0.147070  ...       -0.267173
# ..            ...        ...       ...       ...  ...             ...
# 135      0.408993   0.827226  0.571474  0.243542  ...       -1.332704
# 136      0.038983  -0.744041 -0.635071 -0.280162  ...        1.264164
# 137     -0.731870  -0.528377  0.446659  0.987752  ...       -0.692221
# 138      0.378159  -0.281904  0.405054  0.147070  ...       -0.837785
# 139     -1.934401  -1.606698 -2.465691 -2.443883  ...        1.566937
#
#      solarenergy   uvindex  conditions         city_id        lon         lat  \
# 0      -0.587471 -0.373310           4  biala_podlaska  52.033333   23.116667
# 1      -0.720340 -1.485297           3  biala_podlaska  52.033333   23.116667
# 2      -1.052512 -0.373310           2  biala_podlaska  52.033333   23.116667
# 3       1.339130  1.850664           2  biala_podlaska  52.033333   23.116667
# 4      -0.188864 -0.373310           2  biala_podlaska  52.033333   23.116667
# ..           ...       ...         ...             ...        ...         ...
# 135    -1.384685 -1.485297           2           lomza  53.176389   22.073056
# 136     1.272695  0.738677           3           lomza  53.176389   22.073056
# 137    -0.653905 -0.373310           4           lomza  53.176389   22.073056
# 138    -0.786774 -0.373310           4           lomza  53.176389   22.073056
# 139     1.737737  0.738677           1           lomza  53.176389   22.073056
#
#       area  density  no_people
# 0    49.40  1152.06      56942
# 1    49.40  1152.06      56942
# 2    49.40  1152.06      56942
# 3    49.40  1152.06      56942
# 4    49.40  1152.06      56942
# ..     ...      ...        ...
# 135  32.67  1915.30      62573
# 136  32.67  1915.30      62573
# 137  32.67  1915.30      62573
# 138  32.67  1915.30      62573
# 139  32.67  1915.30      62573
#
# [140 rows x 30 columns]
#            date            city   tempmax   tempmin      temp  feelslikemax  \
# 0    2023-01-13  biała podlaska  0.276841 -0.187344  0.141378      0.439827
# 1    2023-01-14  biała podlaska  0.490736  0.257201  0.283774      0.717334
# 2    2023-01-15  biała podlaska -0.108170 -0.039162  0.046448      0.223988
# 3    2023-01-16  biała podlaska -0.150949  0.257201 -0.001017      0.008149
# 4    2023-01-17  biała podlaska  0.020167  0.553563  0.283774     -0.516031
# ..          ...             ...       ...       ...       ...           ...
# 135  2023-01-15           łomża -0.193728  0.355988  0.283774      0.408993
# 136  2023-01-16           łomża -0.664297 -0.533100 -0.570599      0.038983
# 137  2023-01-17           łomża -0.108170  0.109019 -0.001017     -0.731870
# 138  2023-01-18           łomża  1.474654  0.109019  0.426170      0.378159
# 139  2023-01-19           łomża -1.092087 -1.027038 -1.187647     -1.934401
#
#      feelslikemin  feelslike       dew  humidity  ...  solarradiation  \
# 0        0.439827   0.087806  0.571474  0.794808  ...       -0.663108
# 1        0.717334   0.765608  0.779499  0.670773  ...       -0.756269
# 2        0.223988   0.703990  0.238634 -0.073437  ...       -1.012462
# 3        0.008149  -0.251095  0.113819  0.298668  ...        1.479599
# 4       -0.516031  -0.251095  0.280239  0.147070  ...       -0.267173
# ..            ...        ...       ...       ...  ...             ...
# 135      0.408993   0.827226  0.571474  0.243542  ...       -1.332704
# 136      0.038983  -0.744041 -0.635071 -0.280162  ...        1.264164
# 137     -0.731870  -0.528377  0.446659  0.987752  ...       -0.692221
# 138      0.378159  -0.281904  0.405054  0.147070  ...       -0.837785
# 139     -1.934401  -1.606698 -2.465691 -2.443883  ...        1.566937
#
#      solarenergy   uvindex  conditions         city_id        lon         lat  \
# 0      -0.587471 -0.373310           4  biala_podlaska  52.033333   23.116667
# 1      -0.720340 -1.485297           3  biala_podlaska  52.033333   23.116667
# 2      -1.052512 -0.373310           2  biala_podlaska  52.033333   23.116667
# 3       1.339130  1.850664           2  biala_podlaska  52.033333   23.116667
# 4      -0.188864 -0.373310           2  biala_podlaska  52.033333   23.116667
# ..           ...       ...         ...             ...        ...         ...
# 135    -1.384685 -1.485297           2           lomza  53.176389   22.073056
# 136     1.272695  0.738677           3           lomza  53.176389   22.073056
# 137    -0.653905 -0.373310           4           lomza  53.176389   22.073056
# 138    -0.786774 -0.373310           4           lomza  53.176389   22.073056
# 139     1.737737  0.738677           1           lomza  53.176389   22.073056
#
#       area  density  no_people
# 0    49.40  1152.06      56942
# 1    49.40  1152.06      56942
# 2    49.40  1152.06      56942
# 3    49.40  1152.06      56942
# 4    49.40  1152.06      56942
# ..     ...      ...        ...
# 135  32.67  1915.30      62573
# 136  32.67  1915.30      62573
# 137  32.67  1915.30      62573
# 138  32.67  1915.30      62573
# 139  32.67  1915.30      62573
#
# [140 rows x 30 columns]
